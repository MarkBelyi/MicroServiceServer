# %%
import pandas as pd

# %%
data = pd.read_excel('synthetic_dataset_BETA_3.xlsx')

# %%
print(data.columns)
# Out:
# Index(['Product_Name', 'Subgroup', 'Company', 'Start_Expiry_Date',
#        'End_Expiry_Date', 'Purchase_Date', 'Sales_Date', 'Quantity_Sold',
#        'Purchase_Price', 'Selling_Price', 'Stock_Left', 'Returns', 'Region',
#        'Season', 'Holiday', 'Discount'],
#       dtype='object')
